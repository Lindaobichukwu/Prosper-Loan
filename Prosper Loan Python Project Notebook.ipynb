# %% [markdown]
# # Python Project - (Dataset Exploration Title)
#
# ## by LINDA OBICHUKWU
#
# ## Introduction
#
# ## This dataset belongs to a Loan Company called Proper Loan.
#
# ## It has 113,937 rows and 81 columns.

# %% [markdown]
# ### Importing Libraries

# %%
# import all packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Dataset

# %%
import pandas as pd
df = pd.read_csv('Prosper Loan.csv')

# %% [markdown]
# ### Data Exploration

# %%
df.describe()
# Out:
#        ListingNumber           Term    BorrowerAPR   BorrowerRate  \
# count   1.139370e+05  113937.000000  113912.000000  113937.000000
# mean    6.278857e+05      40.830248       0.218828       0.192764
# std     3.280762e+05      10.436212       0.080364       0.074818
# min     4.000000e+00      12.000000       0.006530       0.000000
# 25%     4.009190e+05      36.000000       0.156290       0.134000
# 50%     6.005540e+05      36.000000       0.209760       0.184000
# 75%     8.926340e+05      36.000000       0.283810       0.250000
# max     1.255725e+06      60.000000       0.512290       0.497500
#
#          LenderYield  EstimatedEffectiveYield  EstimatedLoss  EstimatedReturn  \
# count  113937.000000             84853.000000   84853.000000     84853.000000
# mean        0.182701                 0.168661       0.080306         0.096068
# std         0.074516                 0.068467       0.046764         0.030403
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ListingKey                           113937 non-null  object
#  1   ListingNumber                        113937 non-null  int64
#  2   ListingCreationDate                  113937 non-null  object
#  3   CreditGrade                          28953 non-null   object
#  4   Term                                 113937 non-null  int64
#  5   LoanStatus                           113937 non-null  object
#  6   ClosedDate                           55089 non-null   object
#  7   BorrowerAPR                          113912 non-null  float64
#  8   BorrowerRate                         113937 non-null  float64
#  9   LenderYield                          113937 non-null  float64
# ...

# %% [markdown]
# >>These dataset belongs to Prosper Loan Company and it has 81 columns and 113,937 rows.
#
# >>It also contains the following datatypes boolean (3), float (49), int (12) and object (17).
#
# >>My main feature of interest is to find out the Income Range of the borrowers and the Loan Original Amount.
#
# >>The features in the dataset that will help me support my investigation into my feature(s) of interest are the Stated Monthly Income, Monthly Loan Payment, Prosper Loan Scores, the Loan status, the Loan Original amount etc.

# %% [markdown]
# ### Data Visualization(Univariate Exploration)

# %%
df.IncomeRange.value_counts()
# Out:
# IncomeRange
# $25,000-49,999    32192
# $50,000-74,999    31050
# $100,000+         17337
# $75,000-99,999    16916
# Not displayed      7741
# $1-24,999          7274
# Not employed        806
# $0                  621
# Name: count, dtype: int64

# %%
plt.hist(data = df, x = 'LoanMonthsSinceOrigination', color = 'darkorange')
plt.title('Loan Months Since Origination Distribution')
plt.xlabel('Loan Months Since Origination')
plt.ylabel('Frequency');

# %%
df.LoanMonthsSinceOrigination.value_counts()
# Out:
# LoanMonthsSinceOrigination
# 2      5865
# 3      5215
# 5      4899
# 1      4485
# 4      4336
#        ...
# 56       20
# 58       13
# 100      13
# 99        9
# 98        8
# Name: count, Length: 94, dtype: int64

# %% [markdown]
# >>The plot above is a histogram plot of Loan Months Since Origination.
#
# >>It shows the number of months since the loan originated.
#
# >>From the visualization, 2 months has the highest number with 5,865 of Loan Origination. Followed by 3 months with a total number of 5,215 Loan Origination.
# >> The least number of month is 98 months with a total number of 8 Loan Origination and the second least is 99 months with 9 Loan Origination.
#
# >>I observed that the lesser the months, the more number of Loan Origination. The more the months, the less the loan exist.
# Meaning it takes the borrowers more months to pay their debts as regards to less months.

# %%
plt.hist(data = df, x = 'LoanOriginalAmount', color = 'purple')
plt.title('Loan Original Amount Distribution')
plt.xlabel('Loan Original Amount')
plt.ylabel('Frequency');

# %%
df.LoanOriginalAmount.value_counts()
# Out:
# LoanOriginalAmount
# 4000     14333
# 15000    12407
# 10000    11106
# 5000      6990
# 2000      6067
#          ...
# 5284         1
# 7936         1
# 1201         1
# 10593        1
# 4292         1
# Name: count, Length: 2468, dtype: int64

# %%
df.LoanOriginalAmount.describe()
# Out:
# count    113937.00000
# mean       8337.01385
# std        6245.80058
# min        1000.00000
# 25%        4000.00000
# 50%        6500.00000
# 75%       12000.00000
# max       35000.00000
# Name: LoanOriginalAmount, dtype: float64

# %% [markdown]
# >>The plot above is a histogram plot of Loan Original Amount.
#
# >>From the visualization, the highest amount of Loan Origination awarded is 4,000 to 14,333 borrowers, followed by 15,000 to 12,407 borrowers and thirdly is 10,000 to 11,106 borrowers.
#
# >>The lowest amount of Loan Origination awarded is 4,292 to one borrower, next is 10,593 to one borrower and thirdly is 1,201 to one borrower.

# %%
pd.set_option('display.max_rows', None)

# %%
df.LoanOriginalAmount.describe()
# Out:
# count    113937.00000
# mean       8337.01385
# std        6245.80058
# min        1000.00000
# 25%        4000.00000
# 50%        6500.00000
# 75%       12000.00000
# max       35000.00000
# Name: LoanOriginalAmount, dtype: float64

# %%
df

# %%
df.dtypes
# Out:
# ListingKey                      object
# ListingNumber                    int64
# ListingCreationDate             object
# CreditGrade                     object
# Term                             int64
#                                 ...
# PercentFunded                  float64
# Recommendations                  int64
# InvestmentFromFriendsCount       int64
# InvestmentFromFriendsAmount    float64
# Investors                        int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ListingKey                           113937 non-null  object
#  1   ListingNumber                        113937 non-null  int64
#  2   ListingCreationDate                  113937 non-null  object
#  3   CreditGrade                          28953 non-null   object
#  4   Term                                 113937 non-null  int64
#  5   LoanStatus                           113937 non-null  object
#  6   ClosedDate                           55089 non-null   object
#  7   BorrowerAPR                          113912 non-null  float64
#  8   BorrowerRate                         113937 non-null  float64
#  9   LenderYield                          113937 non-null  float64
# ...

# %%
plt.hist(data = df, x = 'ProsperScore', color = 'saddlebrown');
plt.title('Prosper Score Distribution')
plt.xlabel('Prosper Score')
plt.ylabel('Frequency');

# %%
df.ProsperScore.value_counts()
# Out:
# ProsperScore
# 4.0     12595
# 6.0     12278
# 8.0     12053
# 7.0     10597
# 5.0      9813
# 3.0      7642
# 9.0      6911
# 2.0      5766
# 10.0     4750
# 11.0     1456
# 1.0       992
# Name: count, dtype: int64

# %%
df.ProsperScore.describe()
# Out:
# count    84853.000000
# mean         5.950067
# std          2.376501
# min          1.000000
# 25%          4.000000
# 50%          6.000000
# 75%          8.000000
# max         11.000000
# Name: ProsperScore, dtype: float64

# %% [markdown]
# >>The plot above is a histogram plot for Prosper Score.
#
# >>Prosper Loan is a custom risk score built using historical Prosper data. The score ranges from 1-11, with 11 being the best, or lowest risk score. The plot has a count of 84,853.
#
# >>The visualization above shows the Prosper Score 4.0 has the highest risk score with a total of 12,595 borrowers. The second Prosper score with the highest risk score is 6.0 with a total of 12,278 borrowers, next is 8.0 with 12,053 borrowers. The least count of prosper score is 1.0 with a total of 992 borrowers.
#
# >>I observed from the plot above that 1.0 been the highest risk score has the lowest number of borrowers and 11.0 been the lowest risk score also has a small number of borrowers. 4.0 is high risk and has the highest number of borrowers.

# %%
plt.bar(df['ProsperRating (Alpha)'].value_counts().index, df['ProsperRating (Alpha)'].value_counts().values, color = 'darkorange')
plt.title('Prosper Rating (Alpha) Distribution')
plt.xlabel('Prosper Rating (Alpha)')
plt.ylabel('Frequency');

# %% [markdown]
# >>The plot above is a bar chart plot for Prosper Rating(Alpha).
#
# >>The bar chart shows Prosper Rating assigned at the time the listing was created: 0 - N/A, 1 - HR, 2 - E, 3 - D, 4 - C, 5 - B, 6 - A, 7 - AA.
#
# >>The Prosper Rating C has the highest Frequency.Next is B.
# >>The rating AA has the lowest frequency.

# %% [markdown]
# ## Bivariate Exploration

# %%
df.BorrowerState.value_counts()
# Out:
# BorrowerState
# CA    14717
# TX     6842
# NY     6729
# FL     6720
# IL     5921
# GA     5008
# OH     4197
# MI     3593
# VA     3278
# NJ     3097
# NC     3084
# WA     3048
# PA     2972
# MD     2821
# MO     2615
# MN     2318
# MA     2242
# CO     2210
# IN     2078
# AZ     1901
# WI     1842
# OR     1817
# TN     1737
# AL     1679
# CT     1627
# SC     1122
# NV     1090
# KS     1062
# KY      983
# OK      971
# LA      954
# UT      877
# AR      855
# MS      787
# NE      674
# ID      599
# NH      551
# NM      472
# RI      435
# HI      409
# WV      391
# DC      382
# MT      330
# DE      300
# VT      207
# AK      200
# SD      189
# IA      186
# WY      150
# ME      101
# ND       52
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df, x='IsBorrowerHomeowner', hue='IncomeRange', width = 0.8)
plt.title('Is Borrower Home Owner By Income Range')
plt.xlabel('Is Borrower Home Owner')
plt.ylabel('Count');

# %%
df.IsBorrowerHomeowner.value_counts()
# Out:
# IsBorrowerHomeowner
# True     57478
# False    56459
# Name: count, dtype: int64

# %%
df.IsBorrowerHomeowner.describe()
# Out:
# count     113937
# unique         2
# top         True
# freq       57478
# Name: IsBorrowerHomeowner, dtype: object

# %% [markdown]
# >>The plot above is a bar plot showing If borrowers are home owners and their Income Range.
#
# >>Is borrower a home owner has a total number of 113,937 borrowers. It has 2 unique values which are TRUE and FALSE.
# >>TRUE has a total number of 57,478 borrowers
# >>False has a total number of 56,459 borrowers
#
# >>From the TRUE visualization, the highest number of Home owners are borrowers within the Income range $50,000 - $74,999, $75,000 - $99,999 and $100,000+ while borrowers within the Income Range $0, $1 - $24,999, $25,000 - 49,999, Not displayed and Unemployed have less number of homes.
#
# >>From the FALSE plot, the highest number of borrowers that are not Home Owners are borrowers within the Income Range $25,000 - $49,999, $50,000 - $74,999 and $75,000 - $99,999.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns




df = pd.read_csv('Prosper Loan.csv')

plt.scatter(data = df, x = 'LoanOriginalAmount', y = 'IncomeRange', color = 'brown')
plt.title('Loan Original Amount By Income Range')
plt.xlabel('Loan Original Amount')
plt.ylabel('Income Range');

# %%
df.LoanOriginalAmount.describe()
# Out:
# count    113937.00000
# mean       8337.01385
# std        6245.80058
# min        1000.00000
# 25%        4000.00000
# 50%        6500.00000
# 75%       12000.00000
# max       35000.00000
# Name: LoanOriginalAmount, dtype: float64

# %% [markdown]
# >>The chart above is a Bivariate Exploration which shows insights to Loan Original Amount
# >>and the Income range column using a Scatter plot.
#
# >>I wanted to know if Income affected the amount of Loan been granted to borrowers.
#
# >>From the plot, the people with the Income range of $50,000 - 74,999, $75,000 - 99,999 and $100,000+ had more Loan amount given to them.
# >>The people with the least Loan Amount assigned to them where the borrowers who earn $0, next is the Unemployed.

# %% [markdown]
# >>I observed from the scatter plot above, that Income truely affects the amount of Loan individuals are been granted in Prosper Loan Company because the more your Income, the more Loan you will be granted. The less your income, the less loan you will be awarded.

# %%
plt.scatter(data = df, x = 'Investors', y = 'LoanStatus', color = 'tomato')
plt.title('Number of Investors By Loan Status')
plt.xlabel('Number of Investors')
plt.ylabel('Loan Status');

# %% [markdown]
# >>The chart above is a Bivariate Exploration which shows insights to Number of Investors and the Loan Status column using a
# Scatter plot.
#
# >> I wanted to know if Number of Investors affected the current status of the Loan.
#
# >>Fron the Scatter plot above, it is been shown that the Loan status that were Cancelled, had the lowest amount of investors. Followed by the Past Due (>120 days). Third Lowest is the Final Payment In Progress etc.
# >>The Loan Status of the Completed had the most number of Investors. Second highest were the Defaulted and then the Charged Off.

# %% [markdown]
# >>The Visualization and Insights from the plot above shows that, the more investors you get to fund your Loan, the better chances your Loan Status will be Completed but if you have less investors to fund your Loan, your Loan Status will be Cancelled.

# %%
sns.regplot(data=df, x='Term', y='LoanOriginalAmount', color = 'indigo').set(title = 'Loan Original Amount By Term', xlabel = 'Term', ylabel = 'Loan Original Amount');

# %%
df.Term.describe()
# Out:
# count    113937.000000
# mean         40.830248
# std          10.436212
# min          12.000000
# 25%          36.000000
# 50%          36.000000
# 75%          36.000000
# max          60.000000
# Name: Term, dtype: float64

# %%
df.Term.value_counts()
# Out:
# Term
# 36    87778
# 60    24545
# 12     1614
# Name: count, dtype: int64

# %% [markdown]
# >>The chart above is a Bivariate Exploration which shows insights to Loan Original Amount and  the Term(The length of the loan expressed in months) column using a Reg plot.
#
# >>I wanted to know if Loan original amount had any relationship with the lenght of the loan expressed in months.
#
# >>The Reg plot above shows that there are only three Terms to consider(12 months, 36 months and 60 months).
# >>Less Loan was assigned to the 12 months Term borrowers, followed by the 60 months borrowers. The Term 36 months had the most amount of Loan assigned to people.

# %% [markdown]
# >>The insight from the plot above is that the more your Loan Amount the more Term you have to pay back and the Less your Loan amount the less months you have to pay back the Loan owed.
